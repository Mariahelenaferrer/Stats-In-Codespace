# %% [markdown]
# # Jornada do cientista de dados no DNIT

# %% [markdown]
# ## Fontes de dados:
#
# https://servicos.dnit.gov.br/dadosabertos/dataset/?tags=infraestrutura-rodoviaria
#
# https://servicos.dnit.gov.br/dadospnct
#
# https://dados.transportes.gov.br/dataset/renaest
