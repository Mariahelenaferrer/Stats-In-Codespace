# %% [markdown]
# # Distribuições de Probabilidade e Amostragem

# %% [markdown]
# Probabilidade de as pessoas irem trabalhar no centro do Rio de Janeiro.

# %% [markdown]
# Transformando as distribuições
# Trazer o boxplot que não dava para ver e refazer com log
